# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import confusion_matrix, classification_report

# %%
data_folder = '/Users/muhammadtaha/Desktop/Computer Science Project by Muhammad Taha Iqbal/Dataset/Chicken Dataset'

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    zoom_range=0.2,
    shear_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest',
    validation_split=0.2
)

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    data_folder,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='training'
)

validation_generator = val_datagen.flow_from_directory(
    data_folder,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 805 images belonging to 4 classes.
# Found 200 images belonging to 4 classes.

# %%
VGG16

# %%
class_weights = None

# %%
base_model = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

# Freeze MOST layers but not too many
for layer in base_model.layers[:-6]:
    layer.trainable = False

for layer in base_model.layers[-6:]:
    layer.trainable = True

x = base_model.output
x = GlobalAveragePooling2D()(x)

x = BatchNormalization()(x)

x = Dense(256, activation='relu')(x)
x = Dropout(0.4)(x)

x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)

output = Dense(train_generator.num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

model.compile(
    optimizer=Adam(learning_rate=0.0001),   
    loss='categorical_crossentropy',        
    metrics=['accuracy']
)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    min_lr=1e-6
)

# %%
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=40,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weights
)
# Out:
# Epoch 1/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 130s 3s/step - accuracy: 0.6025 - loss: 1.0058 - val_accuracy: 0.6400 - val_loss: 1.5515 - learning_rate: 1.0000e-04
# Epoch 2/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.7528 - loss: 0.6502 - val_accuracy: 0.5800 - val_loss: 2.5609 - learning_rate: 1.0000e-04
# Epoch 3/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.8298 - loss: 0.4885 - val_accuracy: 0.7600 - val_loss: 1.0642 - learning_rate: 1.0000e-04
# Epoch 4/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.8422 - loss: 0.4180 - val_accuracy: 0.7200 - val_loss: 1.2822 - learning_rate: 1.0000e-04
# Epoch 5/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.8658 - loss: 0.3483 - val_accuracy: 0.7350 - val_loss: 1.1517 - learning_rate: 1.0000e-04
# Epoch 6/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.8894 - loss: 0.2800 - val_accuracy: 0.7850 - val_loss: 1.1119 - learning_rate: 1.0000e-04
# Epoch 7/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.9466 - loss: 0.1799 - val_accuracy: 0.8050 - val_loss: 0.9996 - learning_rate: 3.0000e-05
# Epoch 8/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9528 - loss: 0.1511 - val_accuracy: 0.7900 - val_loss: 1.0409 - learning_rate: 3.0000e-05
# Epoch 9/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 126s 2s/step - accuracy: 0.9516 - loss: 0.1551 - val_accuracy: 0.7800 - val_loss: 1.1714 - learning_rate: 3.0000e-05
# Epoch 10/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9503 - loss: 0.1453 - val_accuracy: 0.8000 - val_loss: 1.0444 - learning_rate: 3.0000e-05
# Epoch 11/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9640 - loss: 0.1205 - val_accuracy: 0.7950 - val_loss: 0.9860 - learning_rate: 9.0000e-06
# Epoch 12/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.9652 - loss: 0.1121 - val_accuracy: 0.8000 - val_loss: 0.9440 - learning_rate: 9.0000e-06
# Epoch 13/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.9739 - loss: 0.0970 - val_accuracy: 0.8050 - val_loss: 0.9432 - learning_rate: 9.0000e-06
# Epoch 14/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.9665 - loss: 0.1025 - val_accuracy: 0.8000 - val_loss: 0.9677 - learning_rate: 9.0000e-06
# Epoch 15/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9677 - loss: 0.1138 - val_accuracy: 0.7950 - val_loss: 1.0284 - learning_rate: 9.0000e-06
# Epoch 16/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.9627 - loss: 0.1260 - val_accuracy: 0.7900 - val_loss: 1.0164 - learning_rate: 9.0000e-06
# Epoch 17/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9826 - loss: 0.0820 - val_accuracy: 0.8000 - val_loss: 1.0459 - learning_rate: 2.7000e-06
# Epoch 18/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9702 - loss: 0.0962 - val_accuracy: 0.8000 - val_loss: 1.0226 - learning_rate: 2.7000e-06
# Epoch 19/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9615 - loss: 0.1062 - val_accuracy: 0.8000 - val_loss: 1.0328 - learning_rate: 2.7000e-06
# Epoch 20/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9714 - loss: 0.0979 - val_accuracy: 0.8050 - val_loss: 1.0402 - learning_rate: 1.0000e-06
# Epoch 21/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.9689 - loss: 0.0866 - val_accuracy: 0.8000 - val_loss: 1.0391 - learning_rate: 1.0000e-06
# Epoch 22/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9689 - loss: 0.1049 - val_accuracy: 0.8050 - val_loss: 1.0478 - learning_rate: 1.0000e-06
# Epoch 23/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9702 - loss: 0.0822 - val_accuracy: 0.7900 - val_loss: 1.0397 - learning_rate: 1.0000e-06

# %%
loss, accuracy = model.evaluate(validation_generator)
print("Validation Accuracy:", accuracy)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8050 - loss: 0.9432
# Validation Accuracy: 0.8050000071525574

# %%
validation_generator.reset()

predictions = model.predict(validation_generator)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = validation_generator.classes

confusion_mtx = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(8,6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues',
            xticklabels=validation_generator.class_indices.keys(),
            yticklabels=validation_generator.class_indices.keys())

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print(classification_report(
    true_classes,
    predicted_classes,
    target_names=validation_generator.class_indices.keys()
))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step
#                   precision    recall  f1-score   support
#
#     Anemia Virus       0.81      0.84      0.82        50
#      Bumble Foot       0.94      1.00      0.97        50
# Fowl Pox Disease       0.64      0.64      0.64        50
#  Healthy Chicken       0.82      0.74      0.78        50
#
#         accuracy                           0.81       200
#        macro avg       0.80      0.80      0.80       200
#     weighted avg       0.80      0.81      0.80       200

# %%
metrics_dict = {}
class_names = list(validation_generator.class_indices.keys())

for i, class_name in enumerate(class_names):
    TP = confusion_mtx[i, i]
    FP = confusion_mtx[:, i].sum() - TP
    FN = confusion_mtx[i, :].sum() - TP
    TN = confusion_mtx.sum() - (TP + FP + FN)
    
    metrics_dict[class_name] = {
        'TP': TP,
        'FP': FP,
        'FN': FN,
        'TN': TN
    }

metrics_df = pd.DataFrame(metrics_dict).T

print(metrics_df)
# Out:
#                   TP  FP  FN   TN
# Anemia Virus      42  10   8  140
# Bumble Foot       50   3   0  147
# Fowl Pox Disease  32  18  18  132
# Healthy Chicken   37   8  13  142

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range = range(1, len(training_accuracy) + 1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.title('Model Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
model.save('AImodel_VGG16_Chicken.keras')

# %%
ResNet50

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import confusion_matrix, classification_report

# %%
data_folder = '/Users/muhammadtaha/Desktop/Computer Science Project by Muhammad Taha Iqbal/Dataset/Chicken Dataset'

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    zoom_range=0.2,
    shear_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest',
    validation_split=0.2
)

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    data_folder,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='training'
)

validation_generator = val_datagen.flow_from_directory(
    data_folder,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 805 images belonging to 4 classes.
# Found 200 images belonging to 4 classes.

# %%
class_weights = None

# %%
base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

# Freeze most layers
for layer in base_model.layers[:-15]:
    layer.trainable = False

for layer in base_model.layers[-15:]:
    layer.trainable = True

x = base_model.output
x = GlobalAveragePooling2D()(x)

x = BatchNormalization()(x)

x = Dense(256, activation='relu')(x)
x = Dropout(0.4)(x)

x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)

output = Dense(train_generator.num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=7,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    min_lr=1e-6
)

# %%
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=40,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weights
)
# Out:
# Epoch 1/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 43s 727ms/step - accuracy: 0.5118 - loss: 1.3321 - val_accuracy: 0.7200 - val_loss: 0.8021 - learning_rate: 1.0000e-04
# Epoch 2/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 37s 716ms/step - accuracy: 0.7888 - loss: 0.5837 - val_accuracy: 0.7900 - val_loss: 0.7647 - learning_rate: 1.0000e-04
# Epoch 3/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 37s 730ms/step - accuracy: 0.8609 - loss: 0.3942 - val_accuracy: 0.7900 - val_loss: 0.8074 - learning_rate: 1.0000e-04
# Epoch 4/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 37s 717ms/step - accuracy: 0.8994 - loss: 0.2640 - val_accuracy: 0.8000 - val_loss: 0.8876 - learning_rate: 1.0000e-04
# Epoch 5/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 36s 710ms/step - accuracy: 0.9180 - loss: 0.2168 - val_accuracy: 0.8000 - val_loss: 0.8881 - learning_rate: 1.0000e-04
# Epoch 6/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 36s 707ms/step - accuracy: 0.9180 - loss: 0.2335 - val_accuracy: 0.7900 - val_loss: 0.9465 - learning_rate: 3.0000e-05
# Epoch 7/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 36s 709ms/step - accuracy: 0.9317 - loss: 0.1811 - val_accuracy: 0.7950 - val_loss: 0.9676 - learning_rate: 3.0000e-05
# Epoch 8/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 36s 707ms/step - accuracy: 0.9578 - loss: 0.1336 - val_accuracy: 0.7950 - val_loss: 0.9342 - learning_rate: 3.0000e-05
# Epoch 9/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 36s 709ms/step - accuracy: 0.9516 - loss: 0.1458 - val_accuracy: 0.8050 - val_loss: 0.9322 - learning_rate: 9.0000e-06

# %%
loss, accuracy = model.evaluate(validation_generator)
print("Validation Accuracy:", accuracy)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 460ms/step - accuracy: 0.7900 - loss: 0.7647
# Validation Accuracy: 0.7900000214576721

# %%
validation_generator.reset()

predictions = model.predict(validation_generator)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = validation_generator.classes

confusion_mtx = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(8,6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues',
            xticklabels=validation_generator.class_indices.keys(),
            yticklabels=validation_generator.class_indices.keys())

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print(classification_report(
    true_classes,
    predicted_classes,
    target_names=validation_generator.class_indices.keys()
))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 531ms/step
#                   precision    recall  f1-score   support
#
#     Anemia Virus       0.82      0.80      0.81        50
#      Bumble Foot       0.94      0.98      0.96        50
# Fowl Pox Disease       0.63      0.68      0.65        50
#  Healthy Chicken       0.78      0.70      0.74        50
#
#         accuracy                           0.79       200
#        macro avg       0.79      0.79      0.79       200
#     weighted avg       0.79      0.79      0.79       200

# %%
metrics_dict = {}
class_names = list(validation_generator.class_indices.keys())

for i, class_name in enumerate(class_names):
    TP = confusion_mtx[i, i]
    FP = confusion_mtx[:, i].sum() - TP
    FN = confusion_mtx[i, :].sum() - TP
    TN = confusion_mtx.sum() - (TP + FP + FN)
    
    metrics_dict[class_name] = {
        'TP': TP,
        'FP': FP,
        'FN': FN,
        'TN': TN
    }

metrics_df = pd.DataFrame(metrics_dict).T
print(metrics_df)
# Out:
#                   TP  FP  FN   TN
# Anemia Virus      40   9  10  141
# Bumble Foot       49   3   1  147
# Fowl Pox Disease  34  20  16  130
# Healthy Chicken   35  10  15  140

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range = range(1, len(training_accuracy) + 1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.title('Model Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
model.save('AImodel_ResNet50_Chicken.keras')

# %%
DenseNet121

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import confusion_matrix, classification_report

# %%
data_folder = '/Users/muhammadtaha/Desktop/Computer Science Project by Muhammad Taha Iqbal/Dataset/Chicken Dataset'

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    zoom_range=0.2,
    shear_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest',
    validation_split=0.2
)

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    data_folder,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='training'
)

validation_generator = val_datagen.flow_from_directory(
    data_folder,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 805 images belonging to 4 classes.
# Found 200 images belonging to 4 classes.

# %%
class_weights = None

# %%
base_model = DenseNet121(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

# Freeze most layers but allow deeper learning
for layer in base_model.layers[:-20]:
    layer.trainable = False

for layer in base_model.layers[-20:]:
    layer.trainable = True

x = base_model.output
x = GlobalAveragePooling2D()(x)

x = BatchNormalization()(x)

x = Dense(256, activation='relu')(x)
x = Dropout(0.4)(x)

x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)

output = Dense(train_generator.num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    min_lr=1e-6
)

# %%
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=40,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weights
)
# Out:
# Epoch 1/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 46s 707ms/step - accuracy: 0.4037 - loss: 1.3455 - val_accuracy: 0.6350 - val_loss: 1.0138 - learning_rate: 1.0000e-04
# Epoch 2/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 33s 638ms/step - accuracy: 0.6099 - loss: 0.9273 - val_accuracy: 0.7150 - val_loss: 0.7759 - learning_rate: 1.0000e-04
# Epoch 3/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 34s 674ms/step - accuracy: 0.7230 - loss: 0.7152 - val_accuracy: 0.7350 - val_loss: 0.6426 - learning_rate: 1.0000e-04
# Epoch 4/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 33s 646ms/step - accuracy: 0.7540 - loss: 0.6236 - val_accuracy: 0.7600 - val_loss: 0.5778 - learning_rate: 1.0000e-04
# Epoch 5/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 32s 631ms/step - accuracy: 0.8075 - loss: 0.5355 - val_accuracy: 0.7800 - val_loss: 0.5429 - learning_rate: 1.0000e-04
# Epoch 6/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 32s 634ms/step - accuracy: 0.8335 - loss: 0.4670 - val_accuracy: 0.7950 - val_loss: 0.5158 - learning_rate: 1.0000e-04
# Epoch 7/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 32s 628ms/step - accuracy: 0.8559 - loss: 0.4003 - val_accuracy: 0.7800 - val_loss: 0.5363 - learning_rate: 1.0000e-04
# Epoch 8/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 32s 622ms/step - accuracy: 0.8720 - loss: 0.3543 - val_accuracy: 0.7850 - val_loss: 0.5294 - learning_rate: 1.0000e-04
# Epoch 9/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 32s 628ms/step - accuracy: 0.8882 - loss: 0.3194 - val_accuracy: 0.8050 - val_loss: 0.5357 - learning_rate: 1.0000e-04
# Epoch 10/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 33s 641ms/step - accuracy: 0.8882 - loss: 0.3010 - val_accuracy: 0.8050 - val_loss: 0.5353 - learning_rate: 3.0000e-05
# Epoch 11/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 33s 640ms/step - accuracy: 0.9031 - loss: 0.2738 - val_accuracy: 0.8050 - val_loss: 0.5412 - learning_rate: 3.0000e-05
# Epoch 12/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 32s 619ms/step - accuracy: 0.9019 - loss: 0.2897 - val_accuracy: 0.8000 - val_loss: 0.5443 - learning_rate: 3.0000e-05
# Epoch 13/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 32s 630ms/step - accuracy: 0.8981 - loss: 0.2862 - val_accuracy: 0.8000 - val_loss: 0.5469 - learning_rate: 9.0000e-06
# Epoch 14/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 32s 625ms/step - accuracy: 0.9093 - loss: 0.2673 - val_accuracy: 0.8000 - val_loss: 0.5513 - learning_rate: 9.0000e-06
# Epoch 15/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 32s 630ms/step - accuracy: 0.8957 - loss: 0.2743 - val_accuracy: 0.8050 - val_loss: 0.5526 - learning_rate: 9.0000e-06
# Epoch 16/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 32s 622ms/step - accuracy: 0.9043 - loss: 0.2593 - val_accuracy: 0.8050 - val_loss: 0.5549 - learning_rate: 2.7000e-06

# %%
loss, accuracy = model.evaluate(validation_generator)
print("Validation Accuracy:", accuracy)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 474ms/step - accuracy: 0.7950 - loss: 0.5158
# Validation Accuracy: 0.7950000166893005

# %%
validation_generator.reset()

predictions = model.predict(validation_generator)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = validation_generator.classes

confusion_mtx = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(8,6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues',
            xticklabels=validation_generator.class_indices.keys(),
            yticklabels=validation_generator.class_indices.keys())

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print(classification_report(
    true_classes,
    predicted_classes,
    target_names=validation_generator.class_indices.keys()
))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 627ms/step
#                   precision    recall  f1-score   support
#
#     Anemia Virus       0.83      0.78      0.80        50
#      Bumble Foot       0.96      1.00      0.98        50
# Fowl Pox Disease       0.62      0.70      0.66        50
#  Healthy Chicken       0.78      0.70      0.74        50
#
#         accuracy                           0.80       200
#        macro avg       0.80      0.79      0.80       200
#     weighted avg       0.80      0.80      0.80       200

# %%
metrics_dict = {}
class_names = list(validation_generator.class_indices.keys())

for i, class_name in enumerate(class_names):
    TP = confusion_mtx[i, i]
    FP = confusion_mtx[:, i].sum() - TP
    FN = confusion_mtx[i, :].sum() - TP
    TN = confusion_mtx.sum() - (TP + FP + FN)
    
    metrics_dict[class_name] = {
        'TP': TP,
        'FP': FP,
        'FN': FN,
        'TN': TN
    }

metrics_df = pd.DataFrame(metrics_dict).T
print(metrics_df)
# Out:
#                   TP  FP  FN   TN
# Anemia Virus      39   8  11  142
# Bumble Foot       50   2   0  148
# Fowl Pox Disease  35  21  15  129
# Healthy Chicken   35  10  15  140

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range = range(1, len(training_accuracy) + 1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.title('Model Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
model.save('AImodel_DenseNet121_Chicken.keras')

# %%
MobileNettV2

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import confusion_matrix, classification_report

# %%
data_folder = '/Users/muhammadtaha/Desktop/Computer Science Project by Muhammad Taha Iqbal/Dataset/Chicken Dataset'

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    zoom_range=0.2,
    shear_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest',
    validation_split=0.2
)

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    data_folder,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='training'
)

validation_generator = val_datagen.flow_from_directory(
    data_folder,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 805 images belonging to 4 classes.
# Found 200 images belonging to 4 classes.

# %%
class_weights = None

# %%
base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

# Freeze most layers; fine-tune last 50 layers for small dataset
for layer in base_model.layers[:-50]:
    layer.trainable = False

for layer in base_model.layers[-50:]:
    layer.trainable = True

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)

x = Dense(256, activation='relu')(x)
x = Dropout(0.4)(x)

x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)

output = Dense(train_generator.num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    min_lr=1e-6
)

# %%
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=40,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weights
)
# Out:
# Epoch 1/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 264ms/step - accuracy: 0.4795 - loss: 1.3291 - val_accuracy: 0.5750 - val_loss: 1.1990 - learning_rate: 1.0000e-04
# Epoch 2/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 12s 247ms/step - accuracy: 0.7466 - loss: 0.6627 - val_accuracy: 0.6050 - val_loss: 1.1129 - learning_rate: 1.0000e-04
# Epoch 3/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 12s 239ms/step - accuracy: 0.8248 - loss: 0.4686 - val_accuracy: 0.6300 - val_loss: 1.2372 - learning_rate: 1.0000e-04
# Epoch 4/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 12s 235ms/step - accuracy: 0.8335 - loss: 0.4191 - val_accuracy: 0.6100 - val_loss: 1.5221 - learning_rate: 1.0000e-04
# Epoch 5/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 248ms/step - accuracy: 0.8770 - loss: 0.3363 - val_accuracy: 0.6250 - val_loss: 1.6337 - learning_rate: 1.0000e-04
# Epoch 6/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 12s 238ms/step - accuracy: 0.8994 - loss: 0.2900 - val_accuracy: 0.6400 - val_loss: 1.5766 - learning_rate: 3.0000e-05
# Epoch 7/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 12s 241ms/step - accuracy: 0.9130 - loss: 0.2455 - val_accuracy: 0.6350 - val_loss: 1.5910 - learning_rate: 3.0000e-05
# Epoch 8/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 288ms/step - accuracy: 0.9130 - loss: 0.2588 - val_accuracy: 0.6650 - val_loss: 1.5202 - learning_rate: 3.0000e-05
# Epoch 9/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 271ms/step - accuracy: 0.9168 - loss: 0.2409 - val_accuracy: 0.6850 - val_loss: 1.3623 - learning_rate: 9.0000e-06
# Epoch 10/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 12s 238ms/step - accuracy: 0.9217 - loss: 0.2192 - val_accuracy: 0.6950 - val_loss: 1.3320 - learning_rate: 9.0000e-06
# Epoch 11/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 12s 239ms/step - accuracy: 0.9068 - loss: 0.2741 - val_accuracy: 0.6900 - val_loss: 1.3346 - learning_rate: 9.0000e-06
# Epoch 12/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 12s 237ms/step - accuracy: 0.9317 - loss: 0.1990 - val_accuracy: 0.7000 - val_loss: 1.3209 - learning_rate: 2.7000e-06

# %%
loss, accuracy = model.evaluate(validation_generator)
print("Validation Accuracy:", accuracy)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.6050 - loss: 1.1129
# Validation Accuracy: 0.6050000190734863

# %%
validation_generator.reset()

predictions = model.predict(validation_generator)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = validation_generator.classes

confusion_mtx = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(8,6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues',
            xticklabels=validation_generator.class_indices.keys(),
            yticklabels=validation_generator.class_indices.keys())

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print(classification_report(
    true_classes,
    predicted_classes,
    target_names=validation_generator.class_indices.keys()
))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step
#                   precision    recall  f1-score   support
#
#     Anemia Virus       0.39      0.14      0.21        50
#      Bumble Foot       1.00      0.92      0.96        50
# Fowl Pox Disease       0.38      0.78      0.51        50
#  Healthy Chicken       0.91      0.58      0.71        50
#
#         accuracy                           0.60       200
#        macro avg       0.67      0.60      0.59       200
#     weighted avg       0.67      0.60      0.59       200

# %%
metrics_dict = {}
class_names = list(validation_generator.class_indices.keys())

for i, class_name in enumerate(class_names):
    TP = confusion_mtx[i, i]
    FP = confusion_mtx[:, i].sum() - TP
    FN = confusion_mtx[i, :].sum() - TP
    TN = confusion_mtx.sum() - (TP + FP + FN)
    
    metrics_dict[class_name] = {
        'TP': TP,
        'FP': FP,
        'FN': FN,
        'TN': TN
    }

metrics_df = pd.DataFrame(metrics_dict).T
print(metrics_df)
# Out:
#                   TP  FP  FN   TN
# Anemia Virus       7  11  43  139
# Bumble Foot       46   0   4  150
# Fowl Pox Disease  39  65  11   85
# Healthy Chicken   29   3  21  147

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range = range(1, len(training_accuracy) + 1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.title('Model Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
model.save('AImodel_MobileNetV2_Chicken.keras')

# %%
Vision Transformer (ViT)

# %%
# !pip install vit-keras
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: vit-keras in /opt/anaconda3/envs/LiveStock-HealthMangmentSystem/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/LiveStock-HealthMangmentSystem/lib/python3.11/site-packages (from vit-keras) (1.17.1)
# Requirement already satisfied: validators in /opt/anaconda3/envs/LiveStock-HealthMangmentSystem/lib/python3.11/site-packages (from vit-keras) (0.35.0)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in /opt/anaconda3/envs/LiveStock-HealthMangmentSystem/lib/python3.11/site-packages (from scipy->vit-keras) (2.1.3)
# Requirement already satisfied: tensorflow-addons in /opt/anaconda3/envs/LiveStock-HealthMangmentSystem/lib/python3.11/site-packages (0.23.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /opt/anaconda3/envs/LiveStock-HealthMangmentSystem/lib/python3.11/site-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/LiveStock-HealthMangmentSystem/lib/python3.11/site-packages (from tensorflow-addons) (25.0)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from vit_keras import vit
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight

# %%
data_folder = '/Users/muhammadtaha/Desktop/Computer Science Project by Muhammad Taha Iqbal/Dataset/Chicken Dataset'

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    zoom_range=0.15,
    horizontal_flip=True,
    validation_split=0.2
)

val_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    data_folder,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='training'
)

validation_generator = val_datagen.flow_from_directory(
    data_folder,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 805 images belonging to 4 classes.
# Found 200 images belonging to 4 classes.

# %%
classes = train_generator.classes

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(classes),
    y=classes
)

class_weights = dict(enumerate(class_weights))
print(class_weights)
# Out:
# {0: np.float64(1.00625), 1: np.float64(1.0012437810945274), 2: np.float64(0.9913793103448276), 3: np.float64(1.0012437810945274)}

# %%
vit_model = vit.vit_b16(
    image_size=224,
    pretrained=True,
    include_top=False,
    pretrained_top=False
)

# Freeze most layers, fine-tune last 15
for layer in vit_model.layers[:-15]:
    layer.trainable = False

for layer in vit_model.layers[-15:]:
    layer.trainable = True

x = vit_model.output
x = Flatten()(x)
x = BatchNormalization()(x)

x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)

x = Dense(128, activation='relu')(x)
x = Dropout(0.4)(x)

output = Dense(train_generator.num_classes, activation='softmax')(x)

model = Model(inputs=vit_model.input, outputs=output)

model.compile(
    optimizer=Adam(learning_rate=0.00003),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)
# Out:
# /opt/anaconda3/envs/LiveStock-HealthMangmentSystem/lib/python3.11/site-packages/vit_keras/utils.py:85: UserWarning: Resizing position embeddings from 24, 24 to 14, 14
#   warnings.warn(

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    min_lr=1e-6
)

# %%
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=40,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weights
)
# Out:
# Epoch 1/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 473s 9s/step - accuracy: 0.3280 - loss: 1.8205 - val_accuracy: 0.6550 - val_loss: 0.9939 - learning_rate: 3.0000e-05
# Epoch 2/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 444s 9s/step - accuracy: 0.5342 - loss: 1.2885 - val_accuracy: 0.7500 - val_loss: 0.8420 - learning_rate: 3.0000e-05
# Epoch 3/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 445s 9s/step - accuracy: 0.6584 - loss: 1.0437 - val_accuracy: 0.7900 - val_loss: 0.7679 - learning_rate: 3.0000e-05
# Epoch 4/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 444s 9s/step - accuracy: 0.7180 - loss: 0.9376 - val_accuracy: 0.8150 - val_loss: 0.7275 - learning_rate: 3.0000e-05
# Epoch 5/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 455s 9s/step - accuracy: 0.7590 - loss: 0.8782 - val_accuracy: 0.8550 - val_loss: 0.7003 - learning_rate: 3.0000e-05
# Epoch 6/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 452s 9s/step - accuracy: 0.7963 - loss: 0.7832 - val_accuracy: 0.8450 - val_loss: 0.7247 - learning_rate: 3.0000e-05
# Epoch 7/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 440s 9s/step - accuracy: 0.8335 - loss: 0.7462 - val_accuracy: 0.8350 - val_loss: 0.7279 - learning_rate: 3.0000e-05
# Epoch 8/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 441s 9s/step - accuracy: 0.8745 - loss: 0.6879 - val_accuracy: 0.8350 - val_loss: 0.7402 - learning_rate: 3.0000e-05
# Epoch 9/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 444s 9s/step - accuracy: 0.8832 - loss: 0.6491 - val_accuracy: 0.8400 - val_loss: 0.7371 - learning_rate: 9.0000e-06
# Epoch 10/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 444s 9s/step - accuracy: 0.8820 - loss: 0.6500 - val_accuracy: 0.8400 - val_loss: 0.7296 - learning_rate: 9.0000e-06
# Epoch 11/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 444s 9s/step - accuracy: 0.8870 - loss: 0.6420 - val_accuracy: 0.8350 - val_loss: 0.7379 - learning_rate: 9.0000e-06
# Epoch 12/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 444s 9s/step - accuracy: 0.8882 - loss: 0.6218 - val_accuracy: 0.8450 - val_loss: 0.7345 - learning_rate: 2.7000e-06
# Epoch 13/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 444s 9s/step - accuracy: 0.9106 - loss: 0.6164 - val_accuracy: 0.8500 - val_loss: 0.7341 - learning_rate: 2.7000e-06
# Epoch 14/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 445s 9s/step - accuracy: 0.9143 - loss: 0.6238 - val_accuracy: 0.8500 - val_loss: 0.7349 - learning_rate: 2.7000e-06
# Epoch 15/40
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 445s 9s/step - accuracy: 0.9081 - loss: 0.6180 - val_accuracy: 0.8450 - val_loss: 0.7358 - learning_rate: 1.0000e-06

# %%
loss, accuracy = model.evaluate(validation_generator)
print("Validation Accuracy:", accuracy)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.8550 - loss: 0.7003
# Validation Accuracy: 0.8550000190734863

# %%
validation_generator.reset()

predictions = model.predict(validation_generator)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = validation_generator.classes

confusion_mtx = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(8,6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues',
            xticklabels=validation_generator.class_indices.keys(),
            yticklabels=validation_generator.class_indices.keys())

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print(classification_report(
    true_classes,
    predicted_classes,
    target_names=validation_generator.class_indices.keys()
))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step
#                   precision    recall  f1-score   support
#
#     Anemia Virus       0.80      0.78      0.79        50
#      Bumble Foot       0.93      1.00      0.96        50
# Fowl Pox Disease       0.80      0.70      0.74        50
#  Healthy Chicken       0.89      0.94      0.91        50
#
#         accuracy                           0.85       200
#        macro avg       0.85      0.85      0.85       200
#     weighted avg       0.85      0.85      0.85       200

# %%
metrics_dict = {}
class_names = list(validation_generator.class_indices.keys())

for i, class_name in enumerate(class_names):
    TP = confusion_mtx[i, i]
    FP = confusion_mtx[:, i].sum() - TP
    FN = confusion_mtx[i, :].sum() - TP
    TN = confusion_mtx.sum() - (TP + FP + FN)
    
    metrics_dict[class_name] = {
        'TP': TP,
        'FP': FP,
        'FN': FN,
        'TN': TN
    }

metrics_df = pd.DataFrame(metrics_dict).T
print(metrics_df)
# Out:
#                   TP  FP  FN   TN
# Anemia Virus      39  10  11  140
# Bumble Foot       50   4   0  146
# Fowl Pox Disease  35   9  15  141
# Healthy Chicken   47   6   3  144

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range = range(1, len(training_accuracy) + 1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend()
plt.title('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend()
plt.title('Loss')

plt.show()

# %%
model.save('AImodel_ViT_Chicken.keras')
